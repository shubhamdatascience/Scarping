# %% [markdown]
# # Scraping Hotel Ratings on Tripadvisor

# %% [markdown]
# In this project we will practice web scraping. Let's get some basic information for each hotel in Boston.

# %% [markdown]
# On each hotel page, scrape the Traverler ratings.
#
# ![Information to be scraped](traveler_ratings.png)
#
# Save the data in "traveler_ratings.csv" in the following format:
#
# hotel_name, rating, count
#
# **To receive credit, you must commit traveler_ratings.csv to Github.**

# %%
from bs4 import BeautifulSoup
import sys
import time
import os
import codecs
import json
import requests

base_url = "http://www.tripadvisor.com"

def tourism_page(city, state):


    # EXAMPLE: http://www.tripadvisor.com/Boston

    url = base_url+ "/"+ city
    
    print("URL TO REQUEST: %s \n" % url)
   
    response = requests.get(url);

    html = response.text.encode('utf-8')
   
    
    with open(os.path.join('data/', city + '-search-page.json'), "wb") as h:
        h.write(html)

    soup = BeautifulSoup(html, 'html.parser')
    li = soup.find("link", {"hreflang": "en"})
    return li['href']

# %%
def get_boston_page(tourism_url):
    

    url = tourism_url

   
    response = requests.get(url)
   
    html = response.text.encode('utf-8')

    
    with open(os.path.join('data/', 'Boston' + '-tourism-page.html'), "wb") as h:
        h.write(html)


    
    soup = BeautifulSoup(html, 'html.parser')

    li = soup.find("li", {"class": "hotels twoLines"})
    city_url = li.find('a', href = True)
    print("CITY PAGE URL: %s" % city_url['href'])

    return city_url['href']

# %%
def get_hotel_page(city_url, count):
    

    url = base_url + city_url
    time.sleep(4)
    
    response = requests.get(url)
    html = response.text.encode('utf-8')
    
    with open(os.path.join('data/', 'Boston' + '-hotelist-' + str(count) + '.html'), "wb") as h:
        h.write(html)
    return html

# %%
def get_traveler_rating(hotel_url):
    url = base_url + hotel_url
    hotel_urll.append(url)
    response = requests.get(url)
    html = response.text.encode('utf-8')
    soup = BeautifulSoup(html,'html.parser')
    x = soup.find('label',{'for':'taplc_prodp13n_hr_sur_review_filter_controls_0_filterRating_5'}).findAll('span')[2].find(text=True)
    y = soup.find('label',{'for':'taplc_prodp13n_hr_sur_review_filter_controls_0_filterRating_4'}).findAll('span')[2].find(text=True)
    z = soup.find('label',{'for':'taplc_prodp13n_hr_sur_review_filter_controls_0_filterRating_3'}).findAll('span')[2].find(text=True)
    a = soup.find('label',{'for':'taplc_prodp13n_hr_sur_review_filter_controls_0_filterRating_2'}).findAll('span')[2].find(text=True)
    b = soup.find('label',{'for':'taplc_prodp13n_hr_sur_review_filter_controls_0_filterRating_1'}).findAll('span')[2].find(text=True)
    excellent.append(x)
    very_good.append(y)
    average.append(z)
    poor.append(a)
    terrible.append(b)

# %%
def parse_hotellist_page(html):
 

    soup = BeautifulSoup(html, 'html.parser')


    
    hotel_info = soup.select('div.listing.easyClear.p13n_imperfect')
    for hotel_in in hotel_info:
        name = hotel_in.find('div', {'class' :'listing_title'}).find(text=True)
        hotel_name.append(name)
        href = hotel_in.find('a',{'class':'property_title'},href=True)
        get_traveler_rating(href['href'])
        try:
            rating = hotel_in.find('div', {'class' :'listing_rating'})
        
            reviews = rating.select('span.more.review_count')[0].find(text=True)
            
            stars = hotel_in.find("img", {"class" : "sprite-ratings"})
            
        except Exception as e:
            print("No ratings for this hotel")
            reviews = "N/A"
            stars = 'N/A'

        if stars != 'N/A':
            
            stars = stars['alt'].split()[0]
        print("HOTEL NAME: %s" % name)
        print("HOTEL REVIEWS: %s" % reviews)
        print("HOTEL STAR RATING: %s \n" % stars)

   
    div = soup.select("div.unified.pagination.standard_pagination")[0]
    # check if last page
    if len(div.select('span.nav.next.ui_button.disabled')) > 0:
        print("We reached last page")
        sys.exit()
   
    hrefers = div.findAll('a', href= True)
    for href in hrefers:
        if href.find(text = True) == 'Next':
            print("Next url is %s" % href['href'])
            return href['href']

# %%
current_dir = os.getcwd()
hotel_name = []
excellent = []
very_good = []
average = []
poor = []
terrible = []
hotel_urll = []
# Create data directory if not present
if not os.path.exists(os.path.join(current_dir, 'data/')):
    os.makedirs(os.path.join(current_dir, 'data/'))
    

tourism_url = 'https://www.tripadvisor.com/Tourism-g60745-Boston_Massachusetts-Vacations.html'
#
city_url = get_city_page(tourism_url)
c=0
while(True):
    c+=1
    html = get_hotellist_page(city_url, c)
    city_url = parse_hotellist_page(html)
# Out:
# CITY PAGE URL: /Hotels-g60745-Boston_Massachusetts-Hotels.html
# HOTEL NAME: Marriott Vacation Club Pulse at Custom House, Boston
# HOTEL REVIEWS: 738 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: Boston Harbor Hotel
# HOTEL REVIEWS: 1,725 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: Seaport Boston Hotel
# HOTEL REVIEWS: 4,190 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: Four Seasons Hotel Boston
# HOTEL REVIEWS: 1,488 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: Lenox Hotel
# HOTEL REVIEWS: 3,134 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: Courtyard Boston Copley Square
# HOTEL REVIEWS: 1,566 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: InterContinental Boston
# HOTEL REVIEWS: 3,313 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: Hotel Commonwealth
# HOTEL REVIEWS: 3,983 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: Mandarin Oriental, Boston
# HOTEL REVIEWS: 617 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: Residence Inn Boston Back Bay/Fenway
# HOTEL REVIEWS: 1,262 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: Eliot Hotel
# HOTEL REVIEWS: 1,124 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: XV Beacon
# HOTEL REVIEWS: 1,044 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: Residence Inn Boston Downtown/Seaport
# HOTEL REVIEWS: 413 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: Kimpton Nine Zero Hotel
# HOTEL REVIEWS: 2,434 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: Hilton Garden Inn Boston Logan Airport
# HOTEL REVIEWS: 646 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: The Verb Hotel
# HOTEL REVIEWS: 1,386 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: The Godfrey Hotel Boston
# HOTEL REVIEWS: 1,491 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: enVision Hotel Boston - Longwood
# HOTEL REVIEWS: 556 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: The Langham, Boston
# HOTEL REVIEWS: 2,014 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: Loews Boston Hotel
# HOTEL REVIEWS: 1,357 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: The Boxer Boston
# HOTEL REVIEWS: 889 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: Colonnade Hotel
# HOTEL REVIEWS: 2,908 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: Residence Inn Boston Harbor on Tudor Wharf
# HOTEL REVIEWS: 781 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: Fairmont Copley Plaza, Boston
# HOTEL REVIEWS: 2,586 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: Copley Square Hotel
# HOTEL REVIEWS: 1,516 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: W Boston
# HOTEL REVIEWS: 1,452 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: The Bostonian Boston
# HOTEL REVIEWS: 1,418 Reviews
# HOTEL STAR RATING: 4
#
# HOTEL NAME: Taj Boston
# HOTEL REVIEWS: 2,169 Reviews
# HOTEL STAR RATING: 4
#
# HOTEL NAME: The Westin Copley Place, Boston
# HOTEL REVIEWS: 3,433 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME: Newbury Guest House
# HOTEL REVIEWS: 592 Reviews
# HOTEL STAR RATING: 4
#
# Next url is /Hotels-g60745-oa30-Boston_Massachusetts-Hotels.html#ACCOM_OVERVIEW
# HOTEL NAME: The Ritz-Carlton, Boston
# HOTEL REVIEWS: 589 Reviews
# HOTEL STAR RATING: 4.5
#
# HOTEL NAME
Reviews
# HOTEL STAR RATING: 4
#
# HOTEL NAME: Courtyard Boston Logan Airport
# HOTEL REVIEWS: 649 Reviews
# HOTEL STAR RATING: 3.5
#
# HOTEL NAME: Courtyard Boston-South Boston
# HOTEL REVIEWS: 487 Reviews
# HOTEL STAR RATING: 4
#
# HOTEL NAME: Beacon Hill Hotel and Bistro
# HOTEL REVIEWS: 208 Reviews
# HOTEL STAR RATING: 4
#
# HOTEL NAME: BEST WESTERN PLUS Roundhouse Suites
# HOTEL REVIEWS: 1,056 Reviews
# HOTEL STAR RATING: 3.5
#
# HOTEL NAME: Comfort Inn - Boston
# HOTEL REVIEWS: 234 Reviews
# HOTEL STAR RATING: 3.5
#
# HOTEL NAME: Hotel Boston
# HOTEL REVIEWS: 540 Reviews
# HOTEL STAR RATING: 3.5
#
# HOTEL NAME: Ramada Boston
# HOTEL REVIEWS: 330 Reviews
# HOTEL STAR RATING: 3
#
# HOTEL NAME: Milner Hotel
# HOTEL REVIEWS: 555 Reviews
# HOTEL STAR RATING: 3
#
# HOTEL NAME: The Boston Common Hotel and Conference Center
# HOTEL REVIEWS: 763 Reviews
# HOTEL STAR RATING: 3
#
# HOTEL NAME: Constitution Inn
# HOTEL REVIEWS: 678 Reviews
# HOTEL STAR RATING: 3
#
# HOTEL NAME: Americas Best Value Inn
# HOTEL REVIEWS: 23 Reviews
# HOTEL STAR RATING: 3
#
# HOTEL NAME: Days Hotel Boston-Harvard Fenway
# HOTEL REVIEWS: 326 Reviews
# HOTEL STAR RATING: 2.5
#
# We reached last page
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# To exit: use 'exit', 'quit', or Ctrl-D.

# %%
import pandas as pd
from pandas import Series, DataFrame
df = pd.DataFrame()
df['Name']=hotel_name
df['Excellent']=excellent
df['Very_Good']=very_good
df['Average']=average
df['Poor']=poor
df['Terrible']=terrible

# %%
df.to_csv('traveler_ratings.csv')
new_df = pd.read_csv('traveler_ratings.csv')

# %% [markdown]
# -------

# %% [markdown]
# Next, scrape all the reviews of each hotel for the star ratings of the following attributes: Value, Location, Sleep Quality, Rooms, Cleanliness, Service. Note that some reviews may not have attribute ratings and some may only have some of the attributes. **(25 pts)**
#
# ![Information to be scraped](attribute_ratings.png)
#
# Save the data in "attribute_ratings.csv" in the following format:
#
# hotel_name, review_id, attribute, star_value
#
# **To receive credit, you must commit attribute_ratings.csv to Github.**

# %%
#find the link of first review of each hotel
showreview = []
for i in range(len(hotel_urll)):
    response = requests.get(hotel_urll[i])
    html = response.text.encode('utf-8')
    soup = BeautifulSoup(html,'html.parser')
    hotel_href = soup.find('div', {'class' :'innerBubble'})
    hotel_href = hotel_href.find('a')
    hotel_href = base_url + hotel_href.get('href')
    showreview.append(hotel_href)

# %%
#showreview
data = {}
data = {'name':hotel_name,'showreview':showreview}
df = pd.DataFrame.from_dict(data,orient = 'columns')
df.to_csv('showreview_link.csv')

# %%
import pandas as pd
from pandas import Series, DataFrame
new_df = pd.read_csv('showreview_link.csv')
new_df
# Out:
#     Unnamed: 0                                               name  \
# 0            0  Marriott Vacation Club Pulse at Custom House, ...
# 1            1                                Boston Harbor Hotel
# 2            2                               Seaport Boston Hotel
# 3            3                          Four Seasons Hotel Boston
# 4            4                                        Lenox Hotel
# 5            5                     Courtyard Boston Copley Square
# 6            6                            InterContinental Boston
# 7            7                                 Hotel Commonwealth
# 17  http://www.tripadvisor.com/ShowUserReviews-g60...
# 18  http://www.tripadvisor.com/ShowUserReviews-g60...
# 19  http://www.tripadvisor.com/ShowUserReviews-g60...
# 20  http://www.tripadvisor.com/ShowUserReviews-g60...
# 21  http://www.tripadvisor.com/ShowUserReviews-g60...
# 22  http://www.tripadvisor.com/ShowUserReviews-g60...
# 23  http://www.tripadvisor.com/ShowUserReviews-g60...
# 24  http://www.tripadvisor.com/ShowUserReviews-g60...
# 25  http://www.tripadvisor.com/ShowUserReviews-g60...
# 26  http://www.tripadvisor.com/ShowUserReviews-g60...
# 27  http://www.tripadvisor.com/ShowUserReviews-g60...
# 28  http://www.tripadvisor.com/ShowUserReviews-g60...
# 29  http://www.tripadvisor.com/ShowUserReviews-g60...
# ..                                                ...
# 52  http://www.tripadvisor.com/ShowUserReviews-g60...
# 53  http://www.tripadvisor.com/ShowUserReviews-g60...
# 54  http://www.tripadvisor.com/ShowUserReviews-g60...
# 55  http://www.tripadvisor.com/ShowUserReviews-g60...
# 56  http://www.tripadvisor.com/ShowUserReviews-g60...
# 57  http://www.tripadvisor.com/ShowUserReviews-g60...
# 58  http://www.tripadvisor.com/ShowUserReviews-g60...
# 59  http://www.tripadvisor.com/ShowUserReviews-g60...
# 60  http://www.tripadvisor.com/ShowUserReviews-g60...
# 61  http://www.tripadvisor.com/ShowUserReviews-g60...
# 62  http://www.tripadvisor.com/ShowUserReviews-g60...
# 63  http://www.tripadvisor.com/ShowUserReviews-g60...
# 64  http://www.tripadvisor.com/ShowUserReviews-g60...
# 65  http://www.tripadvisor.com/ShowUserReviews-g60...
# 66  http://www.tripadvisor.com/ShowUserReviews-g60...
# 67  http://www.tripadvisor.com/ShowUserReviews-g60...
# 68  http://www.tripadvisor.com/ShowUserReviews-g60...
# 69  http://www.tripadvisor.com/ShowUserReviews-g60...
# 70  http://www.tripadvisor.com/ShowUserReviews-g60...
# 71  http://www.tripadvisor.com/ShowUserReviews-g60...
# 72  http://www.tripadvisor.com/ShowUserReviews-g60...
# 73  http://www.tripadvisor.com/ShowUserReviews-g60...
# 74  http://www.tripadvisor.com/ShowUserReviews-g60...
# 75  http://www.tripadvisor.com/ShowUserReviews-g60...
# 76  http://www.tripadvisor.com/ShowUserReviews-g60...
# 77  http://www.tripadvisor.com/ShowUserReviews-g60...
# 78  http://www.tripadvisor.com/ShowUserReviews-g60...
# 79  http://www.tripadvisor.com/ShowUserReviews-g60...
# 80  http://www.tripadvisor.com/ShowUserReviews-g60...
# 81  http://www.tripadvisor.com/ShowUserReviews-g60...
#
# [82 rows x 3 columns]

# %%
base_url = "http://www.tripadvisor.com"
response = requests.get(new_df.iloc[43,2])
html = response.text.encode('utf-8')
soup = BeautifulSoup(html,'html.parser')
hotel_href = soup.findAll('div', {'class' :'reviewSelector'})

# %%
len(hotel_href)
# Out:
# 7

# %%
#find value in one review
value = hotel_href[0].findAll('div', {'class' :'recommend-description'})
value
value_onereview = []
for i in range(len(value)):
    a = value[i]
    b = str(a)
    c = b.split('>')
    d = c[1].split('<')
    e = d[0]
    value_onereview.append(e)
value_onereview
# Out:
# ['Location', 'Rooms', 'Service']

# %%
#find alt in one review
alt = hotel_href[5].findAll('span', {'class' :'rate sprite-rating_ss rating_ss'})
alt_onereview = []
for i in range(len(alt)):
    altt = alt[i]
    altt.find_all('img')
    temp = str(altt.find_all('img'))
    temp.index('alt')
    alt_num = temp[temp.index('alt')+5]
    if temp.index('alt')+6 == '.':
        alt_num = int(alt_num)+0.5
    alt_onereview.append(int(alt_num))
alt_onereview
# Out:
# [5, 5, 5]

# %%
import pandas as pd
from pandas import Series, DataFrame
df = pd.DataFrame()
df['review_id'] = []
df['hotel_name'] = []
df['Location'] = []
df['Sleep Quality'] = []
df['Rooms'] = []
df['Service']  = []
df['Value'] = []
df['Cleanliness'] = []
df
# Out:
# Empty DataFrame
# Columns: [review_id, hotel_name, Location, Sleep Quality, Rooms, Service, Value, Cleanliness]
# Index: []

# %%
#get review information for every review
utl_review_id = []
utl_hotel_name = []
utl_Location = []
utl_Sleep_Quality = []
utl_Rooms = []
utl_Service = []
utl_Value = []
utl_Cleanliness = []
review_id = []
while(True):    
    for j in range(len(hotel_href)):
        review_id.append(hotel_href[j].get('id'))
        #find value in one review
        value = hotel_href[j].findAll('div', {'class' :'recommend-description'})
        #print(value)
        value_onereview = []
        for i in range(len(value)):
            a = value[i]
            b = str(a)
            c = b.split('>')
            d = c[1].split('<')
            e = d[0]
            value_onereview.append(e)
       
        alt = hotel_href[j].findAll('span', {'class' :'rate sprite-rating_ss rating_ss'})
        alt_onereview = []
        for i in range(len(alt)):
            alta = alt[i]
            alta.find_all('img')
            temp = str(alta.find_all('img'))
            temp.index('alt')
            alt_num = temp[temp.index('alt')+5]
            ab = float(alt_num)
            if temp[temp.index('alt')+6] == '.':
                ab = ab + 0.5
            alt_onereview.append(ab)
      
        count = 0
        utl_review_id.append(review_id[j]) 
        utl_hotel_name.append(new_df.iloc[43,1])
        x = True
        y = True
        z = True
        a = True
        b = True
        c = True
        for i in range(len(value_onereview)):
            if ('Location' == value_onereview[i]) & x:
                utl_Location.append(alt_onereview[count])
                count+=1
                x = False
                continue
            if ('Sleep Quality' == value_onereview[i]) & y:
                utl_Sleep_Quality.append(alt_onereview[count])
                count+=1
                y = False
                continue
            if ('Rooms' == value_onereview[i]) & z:
                utl_Rooms.append(alt_onereview[count])
                count+=1
                z = False
                continue
            if ('Service' == value_onereview[i]) & a:
                utl_Service.append(alt_onereview[count])
                count+=1
                a = False
                continue
            if ('Value' == value_onereview[i]) & b:
                utl_Value.append(alt_onereview[count])
                count+=1
                b = False
                continue
            if ('Cleanliness' == value_onereview[i]) & c:
                utl_Cleanliness.append(alt_onereview[count])
                count+=1
                c = False
                continue
        if x:
            utl_Location.append(0)
        if y:
            utl_Sleep_Quality.append(0)
        if z:
            utl_Rooms.append(0)
        if a:
            utl_Service.append(0)
        if b:
            utl_Value.append(0)
        if c:
            utl_Cleanliness.append(0)
    hotel_href_findnext = soup.findAll('a', {'class' :'nav next rndBtn ui_button primary taLnk'},href = True)
    if soup.findAll('span',{'class':'nav next disabled'}):
        break
    for href in hotel_href_findnext:
        if href.find(text = True) == 'Next':
            href['href']
        else:
            break
    if href.find(text = True) != 'Next':
        break
    next_url = base_url + href['href']
    next_url
    response = requests.get(next_url)
    html = response.text.encode('utf-8')
    soup = BeautifulSoup(html,'html.parser')
    hotel_href_next = soup.findAll('div', {'class' :'reviewSelector'})
    hotel_href = hotel_href_next

# %%
df['review_id'] = utl_review_id
df['hotel_name'] = utl_hotel_name
df['Location'] = utl_Location
df['Sleep Quality'] = utl_Sleep_Quality
df['Rooms'] = utl_Rooms
df['Service']  = utl_Service
df['Value'] = utl_Value
df['Cleanliness'] = utl_Cleanliness

# %%
import pandas as pd
from pandas import Series, DataFrame
name = []
for i in range(82):
    name.append('attribute_ratings_hotel_{0}'.format(i+1) + '.csv')
name
dff = []
for i in range(82):
    df = pd.read_csv(name[i])
    dff.append(df)

# %%
for i in range(1,82):
    dff[0] = dff[0].append(dff[i],ignore_index=True)
frames = dff[0]

# %%
print(frames.shape)
frames.to_csv('attribute_ratings.csv')
# Out:
# (117383, 9)

# %%
new_df = pd.read_csv('attribute_ratings.csv')
new_df
# Out:
#         Unnamed: 0  Unnamed: 0.1         review_id  \
# 0                0             0  review_433426851
# 1                1             1  review_433022432
# 2                2             2  review_431564898
# 3                3             3  review_428837081
# 4                4             4  review_428185627
# 5                5             5  review_427012974
# 6                6             6  review_426107222
# 7                7             7  review_433426851
# 8                8             8  review_433022432
# 9                9             9  review_431564898
# 10              10            10  review_428837081
# 11              11            11  review_428185627
# 12              12            12  review_427012974
# 13              13            13  review_426107222
# 14              14            14  review_433426851
# 15              15            15  review_433022432
# 16              16            16  review_431564898
# 17              17            17  review_428837081
# 18              18            18  review_428185627
# 19              19            19  review_427012974
# 20              20            20  review_426107222
# 21              21            21  review_433426851
# 22              22            22  review_433022432
# 23              23            23  review_431564898
# 24              24            24  review_428837081
# 25              25            25  review_428185627
# 26              26            26  review_427012974
# 27              27            27  review_426107222
# 28              28            28  review_433426851
# 29              29            29  review_433022432
# ...            ...           ...               ...
# 117353      117353           296  review_432434162
# 117354      117354           297  review_431647561
# 117355      117355           298  review_429751756
# 117356      117356           299  review_429725448
# 117357      117357           300  review_426658425
# 117358      117358           301  review_433408505
# 117359      117359           302  review_433284142
# 117360      117360           303  review_432434162
# 117361      117361           304  review_431647561
# 117362      117362           305  review_429751756
# 117363      117363           306  review_429725448
# 117364      117364           307  review_426658425
# 117365      117365           308  review_433408505
# 117366      117366           309  review_433284142
# 117367      117367           310  review_432434162
# 117368      117368           311  review_431647561
# 117369      117369           312  review_429751756
# 117370      117370           313  review_429725448
# 117371      117371           314  review_426658425
# 117372      117372           315  review_433408505
# 117373      117373           316  review_433284142
# 117374      117374           317  review_432434162
# 117375      117375           318  review_431647561
# 117376      117376           319  review_429751756
# 117377      117377           320  review_429725448
# 117378      117378           321  review_426658425
# 117379      117379           322  review_433408505
# 117380      117380           323  review_433284142
# 117381      117381           324  review_432434162
# 117382      117382           325  review_431647561
#
#                                                hotel_name  Location  \
# 0       Marriott Vacation Club Pulse at Custom House, ...       5.0
# 1       Marriott Vacation Club Pulse at Custom House, ...       0.0
# 2       Marriott Vacation Club Pulse at Custom House, ...       0.0
# 3       Marriott Vacation Club Pulse at Custom House, ...       0.0
# 4       Marriott Vacation Club Pulse at Custom House, ...       5.0
